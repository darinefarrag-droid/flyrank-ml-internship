# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/darinefarrag-droid/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ##1.My lane (or freestyle) and why
# I chose Lane 2: Refresh / Content Opportunity Scoring.
#
# This lane focuses on identifying which pages should be reviewed first for content refresh, expansion, protection, or monitoring. I selected it because content teams often manage a large number of pages, making manual review difficult. Using data-driven analysis can help prioritize pages based on observable search and engagement signals, leading to more efficient decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research Question:
# Which pages should be prioritized for content review and refresh based on their performance signals?
#
# Decision:
# Determine which pages should enter the review queue first.
#
# Action:
# Content managers can review and update the highest-priority pages before focusing on lower-impact pages.
#
# Cost of a Wrong Recommendation:
# A wrong recommendation may cause the team to spend time on pages that do not need attention while missing pages that are actually losing visibility or engagement.
#
# Why Data and ML Can Help:
# The dataset contains thousands of pages and multiple performance signals. Manual review is time-consuming, while data analysis and machine learning can help rank pages and support better decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# I loaded the starter dataset and will use basic dataset statistics to understand its scale and suitability for the Refresh / Content Opportunity Scoring lane. The goal is to confirm that the dataset contains enough pages and variation to support meaningful prioritization decisions.

# %% [markdown]
# The starter dataset contains 30,000 pages and 44 features, providing a substantial amount of information for analysis. The data covers 32 unique clients and 30,000 unique content pages. This scale suggests that manually reviewing every page would be difficult, making a prioritization system valuable. These numbers support the choice of the Refresh / Content Opportunity Scoring lane because the dataset is large enough to explore patterns and identify pages that may benefit from review and refresh actions.

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Rows, Columns:", df.shape)
print("Unique Clients:", df["client_id"].nunique())
print("Unique Content Pages:", df["content_id"].nunique())
# Out:
# Rows, Columns: (30000, 44)
# Unique Clients: 32
# Unique Content Pages: 30000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work is intended as a decision-support tool. It can identify patterns and signals associated with pages that may need review.
#
# However, it cannot prove that refreshing a page will cause traffic growth, nor can it predict Google's algorithms. Any findings should be interpreted as observed and directional rather than causal.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
